# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv("student_data_knn_100_records.csv")
df
# Out:
#     Height  Salary Category
# 0      188   82256      Fit
# 1      178   65222      Fit
# 2      164   93335    Unfit
# 3      157   40965    Unfit
# 4      170   54538    Unfit
# ..     ...     ...      ...
# 95     177   69384      Fit
# 96     156   77254    Unfit
# 97     158   51918    Unfit
# 98     157   90713    Unfit
# 99     161   60306    Unfit
#
# [100 rows x 3 columns]

# %%
x=df[["Height","Salary"]]
y=df["Category"]

print(x.head())
print(y.head())
# Out:
#    Height  Salary
# 0     188   82256
# 1     178   65222
# 2     164   93335
# 3     157   40965
# 4     170   54538
# 0      Fit
# 1      Fit
# 2    Unfit
# 3    Unfit
# 4    Unfit
# Name: Category, dtype: str

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
print(x_scaled[:5])
# Out:
# [[ 1.62593662  0.74392376]
#  [ 0.77287439 -0.0742283 ]
#  [-0.42141274  1.27605401]
#  [-1.01855631 -1.23930489]
#  [ 0.0904246  -0.5873865 ]]

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(x_scaled,y)
print("model trained successfully")
# Out:
# model trained successfully

# %%
new_person=pd.DataFrame({
    "Height":[176],
    "Salary":[7000] 
})

new_person_scalerd=scaler.transform(new_person)
prediction=model.predict(new_person_scalerd)
print(prediction[0])
# Out:
# Unfit
